# %%
products = ["Laptop", "Mobile", "Headphones", "Keyboard", "Mouse", "Monitor"]
sample_product = ("Laptop", 55000, "Electronics")

# %%
print("2nd Product:", products[1])
print("Last Product:", products[-1])
# Out:
# 2nd Product: Mobile
# Last Product: Monitor

# %%
products.append("Tablet")
products.append("Smartwatch")

# %%
print("Updated Products List:")
print(products)
# Out:
# Updated Products List:
# ['Laptop', 'Mobile', 'Headphones', 'Keyboard', 'Mouse', 'Monitor', 'Tablet', 'Smartwatch']

# %% [markdown]
# ## Convert tuple to list, update price, convert back

# %%
temp_list = list(sample_product)
temp_list[1] = 60000
sample_product = tuple(temp_list)

print("Updated Sample Product:", sample_product)
# Out:
# Updated Sample Product: ('Laptop', 60000, 'Electronics')

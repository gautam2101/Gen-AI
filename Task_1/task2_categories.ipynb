# %%
categories = [
    "Electronics",
    "Electronics",
    "Accessories",
    "Accessories",
    "Accessories",
    "Electronics",
    "Electronics",
    "Electronics"
]

# %%
categories_set = set(categories)

print("Unique Categories:")
print(categories_set)
# Out:
# Unique Categories:
# {'Electronics', 'Accessories'}

# %%
categories_set.add("Gaming")

# %%
categories_set.add("Electronics")

# %%
print("After Adding Categories:")
print(categories_set)
# Out:
# After Adding Categories:
# {'Gaming', 'Electronics', 'Accessories'}

# %%
print("Electronics Exists:",
      "Electronics" in categories_set)
# Out:
# Electronics Exists: True

# %%
print("Total Unique Categories:",
      len(categories_set))
# Out:
# Total Unique Categories: 3
